# %%
# Useful starting lines
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

#Imports
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC

# %%
data = pd.read_csv("data/R10.csv") #load the dataset
print(data)
# Out:
#        Unnamed: 0  Unnamed: 0.1  chord altchord  measure  beat  totbeat  \
# 0               0           0.0      R      NaN      1.0   1.0      1.0
# 1               1           1.0    V43      NaN      NaN   1.5      3.5
# 2               2           NaN      I      NaN      3.0   1.0      5.0
# 3               3           3.0     V2      NaN      4.0   1.5      7.5
# 4               4           4.0     I6      NaN      5.0   1.0      NaN
# 5               5           5.0     vi      NaN      5.0   NaN     10.0
# 6               6           NaN      R      NaN      NaN   1.0     11.0
# 7               7           NaN     IV      NaN      NaN   1.0     13.0
# 8               8           8.0    ii6      NaN      NaN   NaN     14.0
# 9               9           NaN     V2      NaN      NaN   3.0     15.0
# 10             10          10.0     I6      NaN      8.0   1.0     16.0
# 11             11          11.0   vi64      NaN      8.0   3.0     18.0
# 12             12          12.0    ii7      NaN      NaN   1.0     19.0
# 13             13          13.0    V43      NaN      NaN   3.0     21.0
# 14             14          14.0     I6      NaN     10.0   1.0     22.0
# 15             15          15.0     I6      NaN     10.0   NaN     23.0
# 16             16          16.0  @none      NaN     10.0   3.0     24.0
# 17             17          17.0     IV      NaN     11.0   1.0     25.0
# 18             18          18.0    ii6      NaN     11.0   NaN     26.0
# 19             19          19.0     V2      NaN     11.0   3.0     27.0
# 20             20          20.0     V2      NaN     12.0   1.0     28.0
# 21             21          21.0     I6      NaN     12.0   NaN     29.0
# 22             22          22.0     IV      NaN     12.0   3.0     30.0
# 23             23          23.0     V7      NaN     13.0   1.0     31.0
# 24             24          24.0   ii43      NaN     13.0   NaN     32.0
# 25             25          25.0    IV6      NaN     13.0   3.0     33.0
# 26             26          26.0   viio      NaN     13.0   3.5     33.5
# 27             27          27.0  I\\\\      NaN     14.0   1.0     34.0
# 28             28          28.0    V43      NaN     14.0   NaN     35.0
# 29             29          29.0     I6      NaN     14.0   3.0     36.0
# ...           ...           ...    ...      ...      ...   ...      ...
# 28065       28065       28065.0     ii      NaN    156.0   1.0    482.5
# 28066       28066       28066.0     ii      NaN    156.0   3.0    484.5
# 28067       28067       28067.0      V      NaN    156.0   4.0    485.5
# 28068       28068       28068.0      I      NaN    157.0   1.0    486.5
# 28069       28069       28069.0     V7      NaN    158.0   1.0    490.5
# 28070       28070       28070.0      I      NaN    159.0   1.0    494.5
# 28071       28071       28071.0     ii      NaN    160.0   1.0    498.5
# 28072       28072       28072.0     ii      NaN    160.0   3.0    500.5
# 28073       28073       28073.0      I      NaN    161.0   1.0    502.5
# 28074       28074       28074.0  V(64)      NaN    161.0   3.0    504.5
# 28075       28075       28075.0     V7      NaN    162.0   1.0    506.5
# 28076       28076       28076.0      I      NaN    163.0   1.0    510.5
# 28077       28077       28077.0      I      NaN    163.0   3.0    512.5
# 28078       28078       28078.0     V2      NaN    164.0   1.0    514.5
# 28079       28079       28079.0     V7      NaN    164.0   3.0    516.5
# 28080       28080       28080.0     I6      NaN    165.0   1.0    518.5
# 28081       28081       28081.0    I64      NaN    165.0   4.0    521.5
# 28082       28082       28082.0     V2      NaN    166.0   1.0    522.5
# 28083       28083       28083.0     V7      NaN    166.0   3.0    524.5
# 28084       28084       28084.0     I6      NaN    167.0   1.0    526.5
# 28085       28085       28085.0    I64      NaN    167.0   4.0    529.5
# 28086       28086       28086.0  @none      NaN    168.0   1.0    530.5
# 28087       28087       28087.0     V7      NaN    168.0   3.0    532.5
# 28088       28088       28088.0     I6      NaN    169.0   1.0    534.5
# 28089       28089       28089.0     V7      NaN    169.0   3.0    536.5
# 28090       28090       28090.0      I      NaN    171.0   1.0    542.5
# 28091       28091       28091.0     V7      NaN    172.0   1.0    546.5
# 28092       28092       28092.0      I      NaN    173.0   1.0    550.5
# 28093       28093       28093.0      V      NaN    174.0   1.0    554.5
# 28094       28094       28094.0  I\\\\      NaN    175.0   1.0    558.5
#
#       timesig   op    no    ...     length  global_key local_key pedal  \
# 0         2/4  127  12.0    ...        2.5          Eb         I   NaN
# 1         2/4  127  12.0    ...        1.5          Eb         I   NaN
# 2         2/4  127  12.0    ...        2.5          Eb         I   NaN
# 3         2/4  127  12.0    ...        1.5          Eb         I   NaN
# 4         2/4  127  12.0    ...        1.0          Eb         I   NaN
# 5         2/4  127  12.0    ...        1.0          Eb         I   NaN
# 6         2/4  127  12.0    ...        NaN          Eb         I   NaN
# 7         3/4  127  12.0    ...        1.0          Eb         I   NaN
# 8         3/4  127  12.0    ...        1.0          Eb         I   NaN
# 9         3/4  127  12.0    ...        1.0          Eb         I   NaN
# 10        3/4  127  12.0    ...        NaN          Eb         I   NaN
# 11        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 12        3/4  127  12.0    ...        NaN          Eb         I   NaN
# 13        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 14        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 15        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 16        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 17        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 18        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 19        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 20        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 21        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 22        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 23        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 24        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 25        3/4  127  12.0    ...        0.5          Eb         I   NaN
# 26        3/4  127  12.0    ...        0.5          Eb         I   NaN
# 27        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 28        3/4  127  12.0    ...        1.0          Eb         I   NaN
# 29        3/4  127  12.0    ...        1.0          Eb         I   NaN
# ...       ...  ...   ...    ...        ...         ...       ...   ...
# 28065     2/2   95  11.0    ...        NaN       false         I   NaN
# 28066     2/2   95  11.0    ...        1.0       false         I   NaN
# 28067     2/2   95  11.0    ...        1.0       false         I   NaN
# 28068     2/2   95  11.0    ...        4.0       false         I   NaN
# 28069     2/2   95  11.0    ...        4.0       false         I   NaN
# 28070     2/2   95  11.0    ...        4.0       false         I   NaN
# 28071     2/2   95  11.0    ...        NaN       false         I   NaN
# 28072     2/2   95  11.0    ...        NaN       false         I   NaN
# 28073     2/2   95  11.0    ...        NaN       false         I   NaN
# 28074     2/2   95  11.0    ...        NaN       false         I   NaN
# 28075     2/2   95  11.0    ...        4.0       false         I   NaN
# 28076     2/2   95  11.0    ...        NaN       false         I   NaN
# 28077     2/2   95  11.0    ...        NaN       false         I   NaN
# 28078     2/2   95  11.0    ...        NaN       false         I   NaN
# 28079     2/2   95  11.0    ...        NaN       false         I   NaN
# 28080     2/2   95  11.0    ...        3.0       false         I   NaN
# 28081     2/2   95  11.0    ...        1.0       false         I   NaN
# 28082     2/2   95  11.0    ...        NaN       false         I   NaN
# 28083     2/2   95  11.0    ...        NaN       false         I   NaN
# 28084     2/2   95  11.0    ...        3.0       false         I   NaN
# 28085     2/2   95  11.0    ...        1.0       false         I   NaN
# 28086     2/2   95  11.0    ...        NaN       false         I   NaN
# 28087     2/2   95  11.0    ...        NaN       false         I   NaN
# 28088     2/2   95  11.0    ...        NaN       false         I   NaN
# 28089     2/2   95  11.0    ...        NaN       false         I   NaN
# 28090     2/2   95  11.0    ...        4.0       false         I   NaN
# 28091     2/2   95  11.0    ...        4.0       false         I   NaN
# 28092     2/2   95  11.0    ...        4.0       false         I   NaN
# 28093     2/2   95  11.0    ...        4.0       false         I   NaN
# 28094     2/2   95  11.0    ...        4.0       false         I   NaN
#
#       numeral form figbass  changes relativeroot phraseend
# 0           I  NaN     NaN      NaN          NaN     False
# 1           V  NaN     NaN      NaN          NaN     False
# 2           I  NaN     NaN      NaN          NaN     False
# 3           V  NaN     NaN      NaN          NaN     False
# 4           I  NaN     NaN      NaN          NaN     False
# 5          vi  NaN     NaN      NaN          NaN     False
# 6          IV  NaN     NaN      NaN          NaN      True
# 7          IV  NaN     NaN      NaN          NaN     False
# 8          ii  NaN     NaN      NaN          NaN     False
# 9           V  NaN     NaN      NaN          NaN     False
# 10          I  NaN     NaN      NaN          NaN     False
# 11         vi  NaN     NaN      NaN          NaN     False
# 12         ii  NaN     NaN      NaN          NaN     False
# 13          V  NaN     NaN      NaN          NaN     False
# 14          I  NaN     NaN        7          NaN     False
# 15          I  NaN     NaN      NaN          NaN     False
# 16        NaN  NaN     NaN      NaN          NaN     False
# 17         IV  NaN     NaN      NaN          NaN     False
# 18         ii  NaN     NaN      NaN          NaN     False
# 19          V  NaN     NaN      NaN          NaN     False
# 20          V  NaN     NaN      NaN          NaN     False
# 21          I  NaN     NaN      NaN          NaN     False
# 22         IV  NaN     NaN      NaN          NaN     False
# 23          V  NaN     NaN      NaN          NaN     False
# 24         ii  NaN     NaN      NaN          NaN     False
# 25         IV  NaN     NaN      NaN          NaN     False
# 26        vii    o     NaN      NaN          NaN     False
# 27          I  NaN     NaN      NaN          NaN      True
# 28          V  NaN     NaN      NaN          NaN     False
# 29          I  NaN     NaN      NaN          NaN     False
# ...       ...  ...     ...      ...          ...       ...
# 28065      ii  NaN     NaN       #7          NaN     False
# 28066      ii  NaN     NaN      NaN          NaN     False
# 28067       V  NaN     NaN      NaN          NaN     False
# 28068       I  NaN     NaN      NaN          NaN     False
# 28069       V  NaN     NaN      NaN          NaN     False
# 28070       I  NaN     NaN      NaN          NaN     False
# 28071      ii  NaN     NaN       #7          NaN     False
# 28072      ii  NaN     NaN      NaN          NaN     False
# 28073       I  NaN     NaN       #9          NaN     False
# 28074       V  NaN     NaN       64          NaN     False
# 28075       V  NaN     NaN      NaN          NaN     False
# 28076       I  NaN     NaN        7          NaN     False
# 28077       I  NaN     NaN      NaN          NaN     False
# 28078       V  NaN     NaN       +4          NaN     False
# 28079       V  NaN     NaN      NaN          NaN     False
# 28080       I  NaN     NaN      NaN          NaN     False
# 28081       I  NaN     NaN      NaN          NaN     False
# 28082       V  NaN     NaN       +4          NaN     False
# 28083       V  NaN     NaN      NaN          NaN     False
# 28084       I  NaN     NaN      NaN          NaN     False
# 28085       I  NaN     NaN      NaN          NaN     False
# 28086     NaN  NaN     NaN      NaN          NaN     False
# 28087       V  NaN     NaN      NaN          NaN     False
# 28088       I  NaN     NaN      NaN          NaN     False
# 28089       V  NaN     NaN      NaN          NaN     False
# 28090       I  NaN     NaN      NaN          NaN     False
# 28091       V  NaN     NaN      NaN          NaN     False
# 28092       I  NaN     NaN      NaN          NaN     False
# 28093       V  NaN     NaN      NaN          NaN     False
# 28094       I  NaN     NaN      NaN          NaN      True
#
# [28095 rows x 21 columns]

# %%
#PLOT FOR 'R' rare labels and then look rather into this! 
data = data[data['chord']=='R']


#Create dataFrame 
df = pd.DataFrame(data)

#Group data by Opus and #Chords for overview
groups = df.groupby(['op','chord'])[['chord']].count().rename(columns={'op':'opus','chord' : 'chord_frequency'})


#Create plot 

plot_df = df.groupby(['op'])[['chord']].count().rename(columns={'op':'opus','chord' : 'chord_frequency'})
ax = plot_df.plot.bar(rot = 0, figsize = [10,5])
ax.set_xlabel("Opus")
ax.set_ylabel("Chord-Frequency")
_=ax.set_title("Chord Frequency of rare chords per opus")

fig = ax.get_figure()
fig.savefig("data/rare_chord_plot.png")

# %%
#Use one-hot encoding/dummy variabes for categorical values
y = pd.get_dummies(y)
tx = pd.get_dummies(tx)

#Replace Nans with zero, since x*nan = nan
tx = tx.replace(np.nan, 0)

tx_cov = tx
#Standardize it? 
tx = (tx-tx.mean())/tx.std()

tx_cov = (tx-tx.mean())
cov = np.dot(tx.T, tx)/tx.shape[0] #Covariance Matrix 

print (tx) 
#Build data 
#X_train, X_test, y_train, y_test = train_test_split(tx, y, test_size = 0.4)


#print(final_opus)

#Create individual dataframes with occurences for each set 

#Merge them and the ncompare 


"""


#Get a list of the amount of opus'
#op_dist = data[['chord']].groupby(by = data['op'])[['chord']].count()


#common_remover = chord_dist[chord_dist[['chord']] > 10].dropna().index.values 
#data = data[data.chord.isin(common)]

#common = chord_dist[chord_dist[['chord']] > 10].dropna()

#common = test_dist[test_dist[['chord']]>0].dropna().index.values
#print(common[['chord']])

#test_iter = data.groupby('op')[data[['chord']]].count()
#print(test_iter)
                               

for counter, opus_value in enumerate(opus_dist[['op']].T):
    chord_dist_iter= data[['chord']].groupby('chord')[['chord']].count()
    common_iter = chord_dist[chord_dist[['op']] == opus_value].dropna() 
    pd.merge(common, common_iter)
    
    #for opus_nr in enumerate opus_dist[['op']:

print(common)
"""

#Remove rare chords
#data = data[data.chord.isin(common)]

#new_chord_dist = data[['chord']].groupby('chord')[['chord']].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e1213a2b4637> in <module>()
#       1
#       2 #Use one-hot encoding/dummy variabes for categorical values
# ----> 3 y = pd.get_dummies(y)
#       4 tx = pd.get_dummies(tx)
#       5
#
# NameError: name 'y' is not defined
